# %% [markdown]
# # Solving Double Integrator with SVP
#
# This notebook shows how to use the proposed structured value-based planning (SVP) approach to generate the state-action $Q$-value function for the classic double integrator problem. The correctness of the solution is verified by trajectory simulations.

# %% [markdown]
# ## Problem Definition
#
# The problem is defined as a unit mass brick moving along the $x$-axis on a frictionless surface, with a control input which provides a horizontal force.
# The brick starts from the position-velocity pair $\left(x, \dot{x}\right)$ and follows the dynamics
#
# \begin{align*}
#     x &:= x + \dot{x}\cdot\tau, \\
#     \dot{x} &:= \dot{x} + u\cdot\tau,
# \end{align*}
#
# where $u \in \left[ -1, 1 \right]$ is the acceleration input, $\tau$ is the time interval between decisions. The brick can take on the state values $\left(x, \dot{x}\right) \in \left[ -3., 3. \right] \times \left[ -3., 3. \right]$. To incentivize getting to the original point of the $x$-axis with minimum control input, the reward function is defined in a quadratic form as
#
# \begin{equation*}
#     r(x,\dot{x}) = - \frac{1}{2} \left( x^2 + \dot{x}^2 \right).
# \end{equation*}

# %% [markdown]
# ## Structured Value-based Planning (SVP)
#
# The proposed structured value-based planning (SVP) approach is based on the $Q$-value iteration. At the $t$-th iteration, instead of a full pass over all state-action pairs:
# - SVP first randomly selects a subset $\Omega$ of the state-action pairs. In particular, each state-action pair in $\mathcal{S}\times\mathcal{A}$ is observed (i.e., included in $\Omega$) independently with probability $p$.
# - For each selected $(s,a)$, the intermediate $\hat{Q}(s,a)$ is computed based on the $Q$-value iteration:
#     \begin{equation*}\hat{Q}(s,a) \leftarrow \sum_{s'} P(s'|s,a) \left( r(s,a) + \gamma \max_{a'} Q^{(t)}(s',a') \right),\quad\forall\:(s,a)\in\Omega.
#     				\end{equation*}
# - The current iteration then ends by reconstructing the full $Q$ matrix with matrix estimation, from the set of observations in $\Omega$. That is, $Q^{(t+1)}=\textrm{ME}\big(\{\hat{Q}(s,a)\}_{(s,a)\in\Omega}\big).$
#
# Overall, each iteration reduces the computation cost by roughly $1-p$.

# %% [markdown]
# Through SVP, we can compute the final state-action $Q$-value function.
# To obtain the optimal policy for state $s$, we compute
#
# \begin{align*}
#     \pi^{\star} \left(s\right) = \mbox{argmax}_{a \in \mathcal{A}} Q^{\star}\left(s, a\right).
# \end{align*}

# %% [markdown]
# ### Generate state-action value function with SVP

# %%
push!(LOAD_PATH, ".")
using MDPs, DoubleIntegrator
mdp = MDP(state_space(), action_space(), transition, reward)
__init__()
policy = value_iteration(mdp, true, "../data/qdi_otf_0.2.csv", true)
print("")  # suppress output
# Out:
# ┌ Info: Recompiling stale cache file /home/yuzhe/.julia/compiled/v0.7/MDPs.ji for MDPs [top-level]
# └ @ Base loading.jl:1185
# ┌ Warning: Use of final value of loop variable `iter` around /home/yuzhe/Research/rl/svp/svp/MDPs.jl:224 is deprecated. In the future the variable will be local to the loop instead.
# └ @ ~/Research/rl/svp/svp/MDPs.jl:224
# ┌ Info: Recompiling stale cache file /home/yuzhe/.julia/compiled/v0.7/DoubleIntegrator.ji for DoubleIntegrator [top-level]
# └ @ Base loading.jl:1185
# /home/yuzhe/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Starting value iteration...
# ┌ Warning: `tic()` is deprecated, use `@time`, `@elapsed`, or calls to `time_ns()` instead.
# │   caller = value_iteration(::MDP, ::Bool, ::String, ::Bool) at MDPs.jl:188
# └ @ MDPs /home/yuzhe/Research/rl/svp/svp/MDPs.jl:188
# ┌ Warning: `toc()` is deprecated, use `@time`, `@elapsed`, or calls to `time_ns()` instead.
# │   caller = macro expansion at pyeval.jl:232 [inlined]
# └ @ Core /home/yuzhe/.julia/packages/PyCall/ttONZ/src/pyeval.jl:232
# elapsed time: 15.638752839 seconds
# Iteration 1: residual = 3.41e+07, cputime = 1.56e+01 sec
# elapsed time: 15.279587034 seconds
# Iteration 2: residual = 3.00e+07, cputime = 1.53e+01 sec
# elapsed time: 15.18904432 seconds
# Iteration 3: residual = 2.65e+07, cputime = 1.52e+01 sec
# elapsed time: 14.144373913 seconds
# Iteration 4: residual = 2.40e+07, cputime = 1.41e+01 sec
# elapsed time: 14.999454485 seconds
# Iteration 5: residual = 2.16e+07, cputime = 1.50e+01 sec
# elapsed time: 15.054567027 seconds
# Iteration 6: residual = 1.93e+07, cputime = 1.51e+01 sec
# elapsed time: 15.315222526 seconds
# Iteration 7: residual = 1.79e+07, cputime = 1.53e+01 sec
# elapsed time: 14.434655064 seconds
# Iteration 8: residual = 1.59e+07, cputime = 1.44e+01 sec
# elapsed time: 15.804483337 seconds
# Iteration 9: residual = 1.48e+07, cputime = 1.58e+01 sec
# elapsed time: 16.293023736 seconds
# Iteration 10: residual = 1.32e+07, cputime = 1.63e+01 sec
# elapsed time: 15.110444494 seconds
# Iteration 11: residual = 1.24e+07, cputime = 1.51e+01 sec
# elapsed time: 15.06144212 seconds
# Iteration 12: residual = 1.15e+07, cputime = 1.51e+01 sec
# elapsed time: 18.526002954 seconds
# Iteration 13: residual = 1.05e+07, cputime = 1.85e+01 sec
# elapsed time: 12.849094301 seconds
# Iteration 14: residual = 9.58e+06, cputime = 1.28e+01 sec
# elapsed time: 13.406831914 seconds
# Iteration 15: residual = 9.25e+06, cputime = 1.34e+01 sec
# elapsed time: 13.107389949 seconds
# Iteration 16: residual = 8.59e+06, cputime = 1.31e+01 sec
# elapsed time: 14.592267158 seconds
# Iteration 17: residual = 8.25e+06, cputime = 1.46e+01 sec
# elapsed time: 13.754368002 seconds
# Iteration 18: residual = 7.58e+06, cputime = 1.38e+01 sec
# elapsed time: 13.036652116 seconds
# Iteration 19: residual = 7.44e+06, cputime = 1.30e+01 sec
# elapsed time: 13.021228302 seconds
# Iteration 20: residual = 6.78e+06, cputime = 1.30e+01 sec
# elapsed time: 13.106542962 seconds
# Iteration 21: residual = 6.58e+06, cputime = 1.31e+01 sec
# elapsed time: 18.516260006 seconds
# Iteration 22: residual = 6.39e+06, cputime = 1.85e+01 sec
# elapsed time: 13.559384895 seconds
# Iteration 23: residual = 6.21e+06, cputime = 1.36e+01 sec
# elapsed time: 12.85678781 seconds
# Iteration 24: residual = 5.79e+06, cputime = 1.29e+01 sec
# elapsed time: 13.992396418 seconds
# Iteration 25: residual = 5.54e+06, cputime = 1.40e+01 sec
# elapsed time: 17.727774059 seconds
# Iteration 26: residual = 5.61e+06, cputime = 1.77e+01 sec
# elapsed time: 14.162502478 seconds
# Iteration 27: residual = 5.26e+06, cputime = 1.42e+01 sec
# elapsed time: 15.393149391 seconds
# Iteration 28: residual = 4.71e+06, cputime = 1.54e+01 sec
# elapsed time: 12.790515177 seconds
# Iteration 29: residual = 4.97e+06, cputime = 1.28e+01 sec
# elapsed time: 15.315357305 seconds
# Iteration 30: residual = 4.70e+06, cputime = 1.53e+01 sec
# elapsed time: 17.85414144 seconds
# Iteration 31: residual = 4.89e+06, cputime = 1.79e+01 sec
# elapsed time: 16.636434626 seconds
# Iteration 32: residual = 4.42e+06, cputime = 1.66e+01 sec
# elapsed time: 17.763984932 seconds
# Iteration 33: residual = 4.24e+06, cputime = 1.78e+01 sec
# elapsed time: 18.234039193 seconds
# Iteration 34: residual = 4.21e+06, cputime = 1.82e+01 sec
# elapsed time: 12.785570772 seconds
# Iteration 35: residual = 4.40e+06, cputime = 1.28e+01 sec
# elapsed time: 12.589079248 seconds
# Iteration 36: residual = 4.41e+06, cputime = 1.26e+01 sec
# elapsed time: 12.909745516 seconds
# Iteration 37: residual = 3.96e+06, cputime = 1.29e+01 sec
# elapsed time: 12.988990225 seconds
# Iteration 38: residual = 4.34e+06, cputime = 1.30e+01 sec
# elapsed time: 13.140358312 seconds
# Iteration 39: residual = 3.82e+06, cputime = 1.31e+01 sec
# elapsed time: 12.966534642 seconds
# Iteration 40: residual = 3.93e+06, cputime = 1.30e+01 sec
# elapsed time: 13.260164623 seconds
# Iteration 41: residual = 3.91e+06, cputime = 1.33e+01 sec
# elapsed time: 13.220091769 seconds
# Iteration 42: residual = 4.04e+06, cputime = 1.32e+01 sec
# elapsed time: 12.984805812 seconds
# Iteration 43: residual = 4.10e+06, cputime = 1.30e+01 sec
# elapsed time: 12.886025507 seconds
# Iteration 44: residual = 3.98e+06, cputime = 1.29e+01 sec
# elapsed time: 12.850596185 seconds
# Iteration 45: residual = 4.11e+06, cputime = 1.29e+01 sec
# elapsed time: 12.884779455 seconds
# Iteration 46: residual = 4.24e+06, cputime = 1.29e+01 sec
# elapsed time: 12.554108126 seconds
# Iteration 47: residual = 3.92e+06, cputime = 1.26e+01 sec
# elapsed time: 12.852274149 seconds
# Iteration 48: residual = 3.75e+06, cputime = 1.29e+01 sec
# elapsed time: 12.748471794 seconds
# Iteration 49: residual = 3.65e+06, cputime = 1.27e+01 sec
# elapsed time: 13.084383944 seconds
# Iteration 50: residual = 4.28e+06, cputime = 1.31e+01 sec
# elapsed time: 12.782006599 seconds
# Iteration 51: residual = 4.04e+06, cputime = 1.28e+01 sec
# elapsed time: 12.915203979 seconds
# Iteration 52: residual = 4.11e+06, cputime = 1.29e+01 sec
# elapsed time: 12.843275563 seconds
# Iteration 53: residual = 3.81e+06, cputime = 1.28e+01 sec
# elapsed time: 12.593883336 seconds
# Iteration 54: residual = 4.10e+06, cputime = 1.26e+01 sec
# elapsed time: 12.759463846 seconds
# Iteration 55: residual = 3.76e+06, cputime = 1.28e+01 sec
# elapsed time: 12.565611239 seconds
# Iteration 56: residual = 3.75e+06, cputime = 1.26e+01 sec
# elapsed time: 12.880939829 seconds
# Iteration 57: residual = 4.08e+06, cputime = 1.29e+01 sec
# elapsed time: 13.084442916 seconds
# Iteration 58: residual = 3.88e+06, cputime = 1.31e+01 sec
# elapsed time: 12.816415734 seconds
# Iteration 59: residual = 3.80e+06, cputime = 1.28e+01 sec
# elapsed time: 12.9095032 seconds
# Iteration 60: residual = 3.72e+06, cputime = 1.29e+01 sec
# elapsed time: 12.942439788 seconds
# Iteration 61: residual = 3.99e+06, cputime = 1.29e+01 sec
# elapsed time: 13.09387685 seconds
# Iteration 62: residual = 3.88e+06, cputime = 1.31e+01 sec
# elapsed time: 12.929398127 seconds
# Iteration 63: residual = 4.12e+06, cputime = 1.29e+01 sec
# elapsed time: 13.152306779 seconds
# Iteration 64: residual = 3.88e+06, cputime = 1.32e+01 sec
# elapsed time: 12.808774451 seconds
# Iteration 65: residual = 3.97e+06, cputime = 1.28e+01 sec
# elapsed time: 13.121844495 seconds
# Iteration 66: residual = 3.76e+06, cputime = 1.31e+01 sec
# elapsed time: 12.479674061 seconds
# Iteration 67: residual = 3.69e+06, cputime = 1.25e+01 sec
# elapsed time: 12.587452388 seconds
# Iteration 68: residual = 3.95e+06, cputime = 1.26e+01 sec
# elapsed time: 12.55831179 seconds
# Iteration 69: residual = 3.95e+06, cputime = 1.26e+01 sec
# elapsed time: 12.588128207 seconds
# Iteration 70: residual = 3.77e+06, cputime = 1.26e+01 sec
# elapsed time: 13.038540971 seconds
# Iteration 71: residual = 3.75e+06, cputime = 1.30e+01 sec
# elapsed time: 12.882822552 seconds
# Iteration 72: residual = 3.98e+06, cputime = 1.29e+01 sec
# elapsed time: 12.853946278 seconds
# Iteration 73: residual = 3.87e+06, cputime = 1.29e+01 sec
# elapsed time: 13.064443162 seconds
# Iteration 74: residual = 3.68e+06, cputime = 1.31e+01 sec
# elapsed time: 12.594078331 seconds
# Iteration 75: residual = 3.92e+06, cputime = 1.26e+01 sec
# elapsed time: 12.83932808 seconds
# Iteration 76: residual = 3.78e+06, cputime = 1.28e+01 sec
# elapsed time: 12.863309675 seconds
# Iteration 77: residual = 4.12e+06, cputime = 1.29e+01 sec
# elapsed time: 12.912476504 seconds
# Iteration 78: residual = 3.86e+06, cputime = 1.29e+01 sec
# elapsed time: 12.911983986 seconds
# Iteration 79: residual = 4.09e+06, cputime = 1.29e+01 sec
# elapsed time: 13.015675329 seconds
# Iteration 80: residual = 3.75e+06, cputime = 1.30e+01 sec
# elapsed time: 13.059482172 seconds
# Iteration 81: residual = 4.19e+06, cputime = 1.31e+01 sec
# elapsed time: 13.034747766 seconds
# Iteration 82: residual = 4.09e+06, cputime = 1.30e+01 sec
# elapsed time: 12.870365771 seconds
# Iteration 83: residual = 3.91e+06, cputime = 1.29e+01 sec
# elapsed time: 12.959003588 seconds
# Iteration 84: residual = 4.05e+06, cputime = 1.30e+01 sec
# elapsed time: 12.628205702 seconds
# Iteration 85: residual = 4.00e+06, cputime = 1.26e+01 sec
# elapsed time: 13.127325629 seconds
# Iteration 86: residual = 4.06e+06, cputime = 1.31e+01 sec
# elapsed time: 12.944599055 seconds
# Iteration 87: residual = 3.97e+06, cputime = 1.29e+01 sec
# elapsed time: 13.128472725 seconds
# Iteration 88: residual = 3.88e+06, cputime = 1.31e+01 sec
# elapsed time: 12.944131404 seconds
# Iteration 89: residual = 3.92e+06, cputime = 1.29e+01 sec
# elapsed time: 13.391308576 seconds
# Iteration 90: residual = 3.63e+06, cputime = 1.34e+01 sec
# elapsed time: 12.825301705 seconds
# Iteration 91: residual = 3.89e+06, cputime = 1.28e+01 sec
# elapsed time: 12.918430871 seconds
# Iteration 92: residual = 3.84e+06, cputime = 1.29e+01 sec
# elapsed time: 12.895050661 seconds
# Iteration 93: residual = 3.99e+06, cputime = 1.29e+01 sec
# elapsed time: 12.997380485 seconds
# Iteration 94: residual = 3.74e+06, cputime = 1.30e+01 sec
# elapsed time: 12.880246934 seconds
# Iteration 95: residual = 4.00e+06, cputime = 1.29e+01 sec
# elapsed time: 12.950380988 seconds
# Iteration 96: residual = 3.94e+06, cputime = 1.30e+01 sec
# elapsed time: 12.923193477 seconds
# Iteration 97: residual = 4.04e+06, cputime = 1.29e+01 sec
# elapsed time: 13.132725757 seconds
# Iteration 98: residual = 3.96e+06, cputime = 1.31e+01 sec
# elapsed time: 13.115098062 seconds
# Iteration 99: residual = 3.94e+06, cputime = 1.31e+01 sec
# elapsed time: 12.919178762 seconds
# Iteration 100: residual = 4.02e+06, cputime = 1.29e+01 sec
# elapsed time: 12.820030716 seconds
# Iteration 101: residual = 4.03e+06, cputime = 1.28e+01 sec
# elapsed time: 12.924643902 seconds
# Iteration 102: residual = 4.11e+06, cputime = 1.29e+01 sec
# elapsed time: 12.84831259 seconds
# Iteration 103: residual = 3.74e+06, cputime = 1.28e+01 sec
# elapsed time: 12.880975712 seconds
# Iteration 104: residual = 3.92e+06, cputime = 1.29e+01 sec
# elapsed time: 12.814302684 seconds
# Iteration 105: residual = 3.94e+06, cputime = 1.28e+01 sec
# elapsed time: 13.046151706 seconds
# Iteration 106: residual = 3.99e+06, cputime = 1.30e+01 sec
# elapsed time: 12.831157354 seconds
# Iteration 107: residual = 3.83e+06, cputime = 1.28e+01 sec
# elapsed time: 13.092026421 seconds
# Iteration 108: residual = 3.70e+06, cputime = 1.31e+01 sec
# elapsed time: 12.865311755 seconds
# Iteration 109: residual = 3.96e+06, cputime = 1.29e+01 sec
# elapsed time: 12.914262302 seconds
# Iteration 110: residual = 4.09e+06, cputime = 1.29e+01 sec
# elapsed time: 13.072066807 seconds
# Iteration 111: residual = 4.01e+06, cputime = 1.31e+01 sec
# elapsed time: 12.63977925 seconds
# Iteration 112: residual = 3.91e+06, cputime = 1.26e+01 sec
# elapsed time: 12.807663336 seconds
# Iteration 113: residual = 3.88e+06, cputime = 1.28e+01 sec
# elapsed time: 13.099889488 seconds
# Iteration 114: residual = 3.70e+06, cputime = 1.31e+01 sec
# elapsed time: 12.952976316 seconds
# Iteration 115: residual = 3.93e+06, cputime = 1.30e+01 sec
# elapsed time: 12.949382461 seconds
# Iteration 116: residual = 3.96e+06, cputime = 1.29e+01 sec
# elapsed time: 12.884321086 seconds
# Iteration 117: residual = 3.98e+06, cputime = 1.29e+01 sec
# elapsed time: 13.256312692 seconds
# Iteration 118: residual = 3.93e+06, cputime = 1.33e+01 sec
# elapsed time: 12.856049092 seconds
# Iteration 119: residual = 4.06e+06, cputime = 1.29e+01 sec
# elapsed time: 12.605612834 seconds
# Iteration 120: residual = 3.93e+06, cputime = 1.26e+01 sec
# elapsed time: 12.920212438 seconds
# Iteration 121: residual = 3.75e+06, cputime = 1.29e+01 sec
# elapsed time: 13.251454447 seconds
# Iteration 122: residual = 3.65e+06, cputime = 1.33e+01 sec
# elapsed time: 12.895522806 seconds
# Iteration 123: residual = 3.89e+06, cputime = 1.29e+01 sec
# elapsed time: 13.039614409 seconds
# Iteration 124: residual = 3.75e+06, cputime = 1.30e+01 sec
# elapsed time: 13.032561426 seconds
# Iteration 125: residual = 3.96e+06, cputime = 1.30e+01 sec
# elapsed time: 12.77061094 seconds
# Iteration 126: residual = 3.95e+06, cputime = 1.28e+01 sec
# elapsed time: 13.066636881 seconds
# Iteration 127: residual = 3.49e+06, cputime = 1.31e+01 sec
# elapsed time: 12.971835221 seconds
# Iteration 128: residual = 3.93e+06, cputime = 1.30e+01 sec
# elapsed time: 12.929475309 seconds
# Iteration 129: residual = 3.91e+06, cputime = 1.29e+01 sec
# elapsed time: 13.128172733 seconds
# Iteration 130: residual = 4.17e+06, cputime = 1.31e+01 sec
# elapsed time: 12.848233592 seconds
# Iteration 131: residual = 4.02e+06, cputime = 1.28e+01 sec
# elapsed time: 13.397219026 seconds
# Iteration 132: residual = 3.93e+06, cputime = 1.34e+01 sec
# elapsed time: 12.569317294 seconds
# Iteration 133: residual = 3.82e+06, cputime = 1.26e+01 sec
# elapsed time: 13.131196328 seconds
# Iteration 134: residual = 3.74e+06, cputime = 1.31e+01 sec
# elapsed time: 12.849944088 seconds
# Iteration 135: residual = 4.11e+06, cputime = 1.28e+01 sec
# elapsed time: 13.171546106 seconds
# Iteration 136: residual = 4.09e+06, cputime = 1.32e+01 sec
# elapsed time: 12.836536842 seconds
# Iteration 137: residual = 3.70e+06, cputime = 1.28e+01 sec
# elapsed time: 13.060633736 seconds
# Iteration 138: residual = 3.73e+06, cputime = 1.31e+01 sec
# elapsed time: 12.834071232 seconds
# Iteration 139: residual = 3.73e+06, cputime = 1.28e+01 sec
# elapsed time: 12.902677048 seconds
# Iteration 140: residual = 3.80e+06, cputime = 1.29e+01 sec
# elapsed time: 12.812740193 seconds
# Iteration 141: residual = 3.69e+06, cputime = 1.28e+01 sec
# elapsed time: 12.956859254 seconds
# Iteration 142: residual = 4.01e+06, cputime = 1.30e+01 sec
# elapsed time: 12.979202219 seconds
# Iteration 143: residual = 3.93e+06, cputime = 1.30e+01 sec
# elapsed time: 13.028898585 seconds
# Iteration 144: residual = 3.84e+06, cputime = 1.30e+01 sec
# elapsed time: 12.729352202 seconds
# Iteration 145: residual = 3.95e+06, cputime = 1.27e+01 sec
# elapsed time: 13.261907461 seconds
# Iteration 146: residual = 3.51e+06, cputime = 1.33e+01 sec
# elapsed time: 12.778755425 seconds
# Iteration 147: residual = 4.06e+06, cputime = 1.28e+01 sec
# elapsed time: 12.875090121 seconds
# Iteration 148: residual = 3.68e+06, cputime = 1.29e+01 sec
# elapsed time: 12.847293427 seconds
# Iteration 149: residual = 4.17e+06, cputime = 1.28e+01 sec
# elapsed time: 12.937481169 seconds
# Iteration 150: residual = 4.04e+06, cputime = 1.29e+01 sec
# elapsed time: 12.964801711 seconds
# Iteration 151: residual = 3.73e+06, cputime = 1.30e+01 sec
# elapsed time: 12.940267995 seconds
# Iteration 152: residual = 3.84e+06, cputime = 1.29e+01 sec
# elapsed time: 12.985174068 seconds
# Iteration 153: residual = 4.02e+06, cputime = 1.30e+01 sec
# elapsed time: 13.208715865 seconds
# Iteration 154: residual = 3.95e+06, cputime = 1.32e+01 sec
# elapsed time: 13.218950235 seconds
# Iteration 155: residual = 3.96e+06, cputime = 1.32e+01 sec
# elapsed time: 12.929116133 seconds
# Iteration 156: residual = 3.87e+06, cputime = 1.29e+01 sec
# elapsed time: 13.192264124 seconds
# Iteration 157: residual = 3.97e+06, cputime = 1.32e+01 sec
# elapsed time: 12.869558382 seconds
# Iteration 158: residual = 3.86e+06, cputime = 1.29e+01 sec
# elapsed time: 12.900827619 seconds
# Iteration 159: residual = 4.01e+06, cputime = 1.29e+01 sec
# elapsed time: 12.657257163 seconds
# Iteration 160: residual = 3.77e+06, cputime = 1.27e+01 sec
# elapsed time: 12.869665296 seconds
# Iteration 161: residual = 3.95e+06, cputime = 1.29e+01 sec
# elapsed time: 13.08265554 seconds
# Iteration 162: residual = 3.81e+06, cputime = 1.31e+01 sec
# elapsed time: 12.915425571 seconds
# Iteration 163: residual = 3.71e+06, cputime = 1.29e+01 sec
# elapsed time: 13.199245892 seconds
# Iteration 164: residual = 3.66e+06, cputime = 1.32e+01 sec
# elapsed time: 12.838641798 seconds
# Iteration 165: residual = 3.92e+06, cputime = 1.28e+01 sec
# elapsed time: 12.946386223 seconds
# Iteration 166: residual = 3.97e+06, cputime = 1.29e+01 sec
# elapsed time: 12.860494011 seconds
# Iteration 167: residual = 3.74e+06, cputime = 1.29e+01 sec
# elapsed time: 12.921074885 seconds
# Iteration 168: residual = 4.05e+06, cputime = 1.29e+01 sec
# elapsed time: 12.870969188 seconds
# Iteration 169: residual = 3.97e+06, cputime = 1.29e+01 sec
# elapsed time: 13.325132043 seconds
# Iteration 170: residual = 3.98e+06, cputime = 1.33e+01 sec
# elapsed time: 12.994227633 seconds
# Iteration 171: residual = 3.93e+06, cputime = 1.30e+01 sec
# elapsed time: 13.016896151 seconds
# Iteration 172: residual = 3.82e+06, cputime = 1.30e+01 sec
# elapsed time: 13.275856084 seconds
# Iteration 173: residual = 3.74e+06, cputime = 1.33e+01 sec
# elapsed time: 12.682897138 seconds
# Iteration 174: residual = 3.82e+06, cputime = 1.27e+01 sec
# elapsed time: 12.891693408 seconds
# Iteration 175: residual = 3.97e+06, cputime = 1.29e+01 sec
# elapsed time: 12.563153505 seconds
# Iteration 176: residual = 3.94e+06, cputime = 1.26e+01 sec
# elapsed time: 12.873098098 seconds
# Iteration 177: residual = 3.84e+06, cputime = 1.29e+01 sec
# elapsed time: 13.111549863 seconds
# Iteration 178: residual = 3.88e+06, cputime = 1.31e+01 sec
# elapsed time: 12.79479292 seconds
# Iteration 179: residual = 3.65e+06, cputime = 1.28e+01 sec
# elapsed time: 13.188398038 seconds
# Iteration 180: residual = 3.65e+06, cputime = 1.32e+01 sec
# elapsed time: 12.944110954 seconds
# Iteration 181: residual = 3.75e+06, cputime = 1.29e+01 sec
# elapsed time: 13.004365977 seconds
# Iteration 182: residual = 3.94e+06, cputime = 1.30e+01 sec
# elapsed time: 12.991949223 seconds
# Iteration 183: residual = 4.03e+06, cputime = 1.30e+01 sec
# elapsed time: 12.957676835 seconds
# Iteration 184: residual = 3.97e+06, cputime = 1.30e+01 sec
# elapsed time: 12.8752191 seconds
# Iteration 185: residual = 4.17e+06, cputime = 1.29e+01 sec
# elapsed time: 12.913624676 seconds
# Iteration 186: residual = 3.81e+06, cputime = 1.29e+01 sec
# elapsed time: 12.572917133 seconds
# Iteration 187: residual = 3.59e+06, cputime = 1.26e+01 sec
# elapsed time: 12.960218101 seconds
# Iteration 188: residual = 3.84e+06, cputime = 1.30e+01 sec
# elapsed time: 12.892769854 seconds
# Iteration 189: residual = 3.97e+06, cputime = 1.29e+01 sec
# elapsed time: 12.985269973 seconds
# Iteration 190: residual = 3.79e+06, cputime = 1.30e+01 sec
# elapsed time: 12.897555655 seconds
# Iteration 191: residual = 4.02e+06, cputime = 1.29e+01 sec
# elapsed time: 12.926733776 seconds
# Iteration 192: residual = 4.10e+06, cputime = 1.29e+01 sec
# elapsed time: 12.815024366 seconds
# Iteration 193: residual = 3.84e+06, cputime = 1.28e+01 sec
# elapsed time: 13.083323514 seconds
# Iteration 194: residual = 3.83e+06, cputime = 1.31e+01 sec
# elapsed time: 12.828151871 seconds
# Iteration 195: residual = 3.92e+06, cputime = 1.28e+01 sec
# elapsed time: 12.669190511 seconds
# Iteration 196: residual = 3.79e+06, cputime = 1.27e+01 sec
# elapsed time: 12.920844187 seconds
# Iteration 197: residual = 4.07e+06, cputime = 1.29e+01 sec
# elapsed time: 12.59288896 seconds
# Iteration 198: residual = 3.96e+06, cputime = 1.26e+01 sec
# elapsed time: 12.837214375 seconds
# Iteration 199: residual = 3.84e+06, cputime = 1.28e+01 sec
# elapsed time: 12.923107891 seconds
# Iteration 200: residual = 3.82e+06, cputime = 1.29e+01 sec
# Warning: maximum number of iterations reached; solution may be inaccurate
# Value iteration took 200 iterations and 2.66e+03 sec

# %% [markdown]
# ### Visualize policy as a heat map

# %%
viz_policy(mdp, policy, "SVP policy (20%)", true, "di/policy_di_0.2.tex")

# %% [markdown]
# ### Verify correctness
# Simulate and visualize trajectory from initial state `[position, speed]`.

# %%
ss, as = simulate(mdp, policy, [-0.5, 0.0])
viz_trajectory(ss, as, "SVP trajectory (20%)", "SVP input (20%)", true, "di/traj_di_0.2.tex")

# %%
nsim = 1000
times = 0
for sim = 1:nsim
    state = [rand(XMIN:0.001 * (XMAX - XMIN):XMAX), 
             rand(VMIN:0.001 * (VMAX - VMIN):VMAX)]
    _, as = simulate(mdp, policy, copy(state))
    times += length(as)
end # for sim
times /= nsim
@printf("average times: %.3f", times)
# Out:
# average times: 199.800
# WARNING: Base.@printf is deprecated: it has been moved to the standard library package `Printf`.
# Add `using Printf` to your imports.
#   likely near /home/yuzhe/.julia/packages/IJulia/gI2uA/src/kernel.jl:52
